# %% [markdown]
# ## Importing the Necessary Libraries

# %%
## numerical and data analysis
import numpy as np
import pandas as pd

## Visualization
import matplotlib.pyplot as plt
import seaborn as sns

## Extra
import warnings
warnings.filterwarnings(action='ignore')

# %%
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# ## Barplot

# %%
# it is used cont (numerical)(y-axis) vs cat(string)(x axis)

# %%
data = {'C':20, 'C++':15, 'Java':30,
        'Python':35}
x=list(data.keys())
y=list(data.values())
plt.figure(figsize=(6,4))
plt.bar(x,y,color=["r","g","y","b"],align="center")
plt.xlabel("Language")
plt.ylabel("No. of Students")
plt.title("No. of students In Every Language Class")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
sns.barplot(x,y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Scatter Plot

# %%
## It is used when we want to see the relationship between two continuous variable

# %%
x =[5, 7, 8, 7, 2, 17, 2, 9,
    4, 11, 12, 9, 6]
 
y =[99, 86, 87, 88, 100, 86,
    103, 87, 94, 78, 77, 85, 86]

plt.scatter(x,y,c="y",edgecolors="black",alpha=1)
plt.show()

# %%
age =[25, 27,28,34, 22, 17, 32, 49,
    24, 41, 22, 19, 26]
 
salary =[25000, 30000, 38000, 20000, 34000, 53000,
    24000, 45000, 22000, 21000, 26000,34000,45000]

plt.scatter(age,salary,c="y",edgecolors="black",alpha=1)
plt.show()

# %%
sns.scatterplot(x,y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Histogram

# %%
## It shows the frequency (count) distribution of bins of continuous variables

# %%
height=[169.1306409 , 163.84124009, 167.10124984, 179.3738896 ,
       175.053351  , 173.83710018, 162.45855653, 161.01145122,
       156.40209873, 178.26124606, 171.75428518, 181.3735809 ,
       157.52042615, 177.71350078, 180.72570822, 168.82938833,
       164.10932312, 165.48455565, 161.17618762, 201.57238501,
       172.88817993, 183.41552194, 158.20590613, 186.98128705,
       164.13027165, 174.94057583, 164.83453225, 191.1888831 ,
       185.08929498, 177.85528832, 174.39807448, 151.94299965,
       177.30872142, 164.92809347, 158.78208659, 168.90643358,
       162.91953601, 179.38693758, 174.30089616, 164.13051211,
       159.03909873, 155.32045427, 158.5737068 , 149.96882981,
       156.9342284 , 155.97990724, 184.19521754, 180.4878051 ,
       174.7816612 , 165.90560317, 155.98050122, 165.03020378,
       167.13948855, 164.83970519, 183.94877994, 178.88136813,
       150.36427277, 154.63733446, 170.29141266, 158.96466034,
       154.42175377, 169.67523045, 173.71229627, 153.77299919,
       179.44051316, 173.73348098, 161.997999  , 185.33256554,
       160.54269261, 167.17080748, 173.16684035, 175.1555027 ,
       188.95284558, 175.49393145, 163.34618894, 149.50234694,
       172.858704  , 184.45640371, 172.59650916, 163.17242492,
       177.37520652, 170.52168126, 165.00309611, 179.70127109,
       163.61219094, 188.46978352, 161.4365229 , 157.93127136,
       153.93206754, 150.01965537, 182.91208042, 165.14244218,
       159.28351293, 161.39070695, 174.2149217 , 176.37768922,
       167.9902852 , 168.65726039, 153.7806187 , 176.09081141,
       180.86015399, 165.21945901, 154.9016857 , 185.28884794,
       153.89644228, 166.92324231, 160.15019208, 171.88530857,
       171.28131012, 179.19945499, 174.89222433, 175.71886732,
       199.74998349, 175.7624729 , 161.90745489, 171.61815866,
       166.64030419, 154.68969332, 167.06651087, 157.21885635,
       160.70448217, 179.20981364, 169.35465589, 163.06140275,
       168.35351658, 165.88169097, 180.66120518, 166.81375243,
       151.87865927, 148.04420027, 148.29763938, 164.5086376 ,
       160.72558612, 178.07432945, 157.96027512, 170.05902085,
       163.29001865, 164.27967727, 158.99818938, 168.69870687,
       169.27901493, 156.50413339, 159.0578826 , 176.21314422,
       183.39681685, 188.7645431 , 195.98108045, 161.43768851,
       174.75289734, 160.50923182, 154.83790422, 181.67027922,
       176.7377802 , 154.8111135 , 175.42213277, 167.00629955,
       174.48362183, 170.91954976, 177.99306356, 179.92773667,
       178.23460403, 168.3896473 , 169.66453251, 167.03583985,
       160.57616913, 167.3931595 , 179.32752277, 179.5587834 ,
       169.2346451 , 162.35427485, 172.14368586, 144.23215902,
       145.6303457 , 172.16144932, 172.44219551, 156.08795594,
       170.52621845, 177.98407603, 177.90568988, 172.35766029,
       171.78603725, 152.93574446, 163.92359776, 172.69354367,
       153.92731653, 160.70839723, 184.77406628, 186.55718817,
       189.79953564, 146.08419917, 170.11473471, 172.91971935,
       167.37933785, 171.94504136, 178.81053288, 176.84905786,
       149.19068795, 175.7989068 , 156.69708652, 143.98195572,
       172.91187075, 169.03463122, 157.64991194, 158.9810459 ,
       173.44274113, 177.73588549, 168.42486567, 159.45335547,
       168.27309251, 164.83852395, 162.89659077, 168.27157443,
       149.47119507, 156.40645649, 178.70287326, 164.74570057,
       156.68167273, 178.9101941 , 180.1231392 , 180.64969152,
       163.18221663, 172.41765759, 164.8343605 , 183.87295753,
       180.9670665 , 167.25779624, 174.87948185, 154.40946137,
       172.56077538, 155.83136317, 188.60740851, 181.11596534,
       180.36098325, 190.46736066, 163.53823941, 164.00462858,
       172.57151482, 169.66232272, 193.15988025, 163.61440219,
       161.19928468, 165.27482751, 156.24349339, 157.3998139 ,
       165.28508684, 182.47865767, 175.29744621, 170.66671645,
       178.79802652, 177.25700109]

# %%
len(height)
# Out:
# 250

# %%
min(height),max(height)
# Out:
# (143.98195572, 201.57238501)

# %%
plt.hist(height,bins=[140,150,160,170,180,190,200,210],edgecolor='black',color="g",alpha=0.5)
plt.show()

# %%
[140,150,160,170,180,190,200,210]--> range(140,220,10)

# %%
sns.histplot(height,bins=range(140,220,10))
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## Boxplot

# %%
## It is used to see quartile distrbution of any cont variable
## It is also used to see whether outliers are present or not

# %%
df=pd.DataFrame(height,columns=["height"])
df.describe()
# Out:
#            height
# count  250.000000
# mean   168.900976
# std     10.830505
# min    143.981956
# 25%    161.052635
# 50%    168.764048
# 75%    176.821238
# max    201.572385

# %%
q1=161.052635
q3=176.821238
iqr=q3-q1
# emperical relationship
lower_bound=q1-1.5*iqr
upper_bound=q3+1.5*iqr
print(lower_bound,upper_bound)
# Out:
# 137.39973050000003 200.47414249999997

# %%
df[df["height"]>upper_bound]
# Out:
#         height
# 19  201.572385

# %%
df[df["height"]<lower_bound]
# Out:
# Empty DataFrame
# Columns: [height]
# Index: []

# %%
plt.boxplot(height)
plt.show()

# %%
# 5 parameter statistical distribution
# 25th percentile (Q1 - First Quartile)
# 50th percentile (Q2 - Second Quartile) (Median)
# 75th percentile (Q3 - Third Quartile)
# Q3-Q1 = Inter-Quartile Range (IQR)
# lower_bound = Q1-1.5*(Q3-Q1)
# upper_bound = Q3+1.5*(Q3-Q1)

# %%
sns.boxplot(y=df["height"])
# Out:
# <AxesSubplot:ylabel='height'>

# %%
x=range(1,10)
y=[i**2 for i in x]
plt.plot(y)

# %% [markdown]
# ## When to choose what
#
# ### Composition
#
# You would need to use a composition chart to display how the various elements make up the complete data. Composition charts can be static, which shows the composition at a particular instance of time, or dynamic, which shows the changes in the composition over a period of time. Two of the popular composition charts are as follows:

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["375 g flour",
          "75 g sugar",
          "250 g butter",
          "300 g berries"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Matplotlib bakery: A pie")

plt.show()

# %%
import matplotlib.pyplot as plt


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()
